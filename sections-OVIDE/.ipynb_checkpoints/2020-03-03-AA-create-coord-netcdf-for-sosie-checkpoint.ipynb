# %%
import xarray as xr
import numpy as np
import pandas as pd
# Out:
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %%
# %load_ext version_information 
# %version_information numpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-2222669f841e> in <module>
# ----> 1 get_ipython().run_line_magic('load_ext', 'version_information ')
#       2 get_ipython().run_line_magic('version_information', 'numpy')
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2312                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2313             with self.builtin_trap:
# -> 2314                 result = fn(*args, **kwargs)
#    2315             return result
#    2316
#
# </scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-64> in load_ext(self, module_str)
#
# ...

# %%
file_OVIDE='/mnt/albert/equipes/meom/DATA_SET/OVIDE/29AH20120623_00001_00001_hy1.nc'

# %%
ds=xr.open_dataset(file_OVIDE)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:             (latitude: 1, longitude: 1, pressure: 24, time: 1)
# Coordinates:
#   * pressure            (pressure) float64 144.5 144.5 144.5 144.5 144.6 ...
#   * time                (time) datetime64[ns] 2012-06-23
#   * latitude            (latitude) float32 40.3326
#   * longitude           (longitude) float32 -9.4594
# Data variables:
#     temperature         (pressure) float64 13.32 13.32 13.32 13.32 13.32 ...
#     salinity            (pressure) float64 35.92 35.92 35.92 35.92 35.92 ...
#     salinity_QC         (pressure) int16 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 ...
#     bottle_salinity     (pressure) float64 35.92 35.92 nan nan nan nan 35.94 ...
#     bottle_salinity_QC  (pressure) int16 2 2 9 9 9 9 2 2 9 9 9 9 2 2 9 9 9 9 ...
#     oxygen              (pressure) float64 201.2 201.2 201.2 201.2 201.2 ...
#     oxygen_QC           (pressure) int16 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 ...
# ...

# %%
p=ds.pressure.values

# %%
print p
# Out:
# [ 144.5  144.5  144.5  144.5  144.6  144.5   99.4   99.4   99.5   99.5
#    99.4   99.4   44.2   44.1   44.2   44.2   44.2   44.1    4.1    4.1
#     4.1    4.     4.1    4.1]

# %%
lat=ds.latitude

# %%
lat.values
# Out:
# array([ 40.33259964], dtype=float32)

# %%
gsw.conversions.z_from_p?

# %%
depth=gsw.conversions.z_from_p(p,lat)

# %%
print depth
# Out:
# [-143.33849256 -143.33849256 -143.33849256 -143.33849256 -143.43765402
#  -143.33849256  -98.61178559  -98.61178559  -98.7109687   -98.7109687
#   -98.61178559  -98.61178559  -43.85537612  -43.75616643  -43.85537612
#   -43.85537612  -43.85537612  -43.75616643   -4.06842856   -4.06842856
#    -4.06842856   -3.96919956   -4.06842856   -4.06842856]

# %%
temp=ds.temperature.values

# %%
print temp.shape
# Out:
# (24,)

# %%
plt.plot(temp,depth)

# %%
latOV=np.zeros(103)
lonOV=np.zeros(103)

list=!ls /mnt/albert/equipes/meom/DATA_SET/OVIDE/29AH20120623_00*_00001_hy1.nc
for t in np.arange(103):
    file_OVIDE=list[t]
    ds=xr.open_dataset(file_OVIDE)
    latOV[t]=ds.latitude.values
    lonOV[t]=ds.longitude.values

# %%
print latOV
# Out:
# [ 40.33259964  40.33319855  40.33440018  40.33359909  40.33069992
#   40.33390045  40.33430099  40.33499908  40.33679962  40.33140182
#   40.33240128  40.33340073  40.3321991   40.55149841  40.78730011
#   41.08459854  41.38359833  41.68190002  41.98329926  42.28170013
#   42.58169937  42.87969971  43.18080139  43.47829819  43.77920151
#   44.07709885  44.37760162  44.67369843  45.05130005  45.42050171
#   45.79349899  46.17029953  46.5447998   46.917099    47.28990173
#   47.66529846  48.03829956  48.4131012   48.7867012   49.15879822
#   49.5306015   49.90430069  50.40380096  50.90200043  51.40119934
#   51.76929855  52.14749908  52.52000046  52.89080048  53.26539993
#   53.6393013   54.26670074  54.76110077  55.32860184  55.88259888
#   56.2519989   56.62779999  57.00400162  57.37779999  57.67490005
#   57.97200012  58.20800018  58.40800095  58.54990005  58.72430038
#   58.84270096  58.91070175  58.97359848  59.04050064  59.10250092
# ...

# %%
print lonOV
# Out:
# [ -9.45940018  -9.63689995  -9.76780033  -9.80200005  -9.87689972
#   -9.9460001  -10.03590012 -10.30119991 -10.57740021 -10.90649986
#  -11.3409996  -11.77950001 -12.21940041 -12.63459969 -13.10029984
#  -13.49230003 -13.88899994 -14.27700043 -14.67300034 -15.06509972
#  -15.45909977 -15.84980011 -16.24349976 -16.63599968 -17.03070068
#  -17.42410088 -17.81459999 -18.20999908 -18.50359917 -18.79579926
#  -19.0897007  -19.3803997  -19.67099953 -19.96949959 -20.26140022
#  -20.55319977 -20.84609985 -21.14139938 -21.43029976 -21.72640038
#  -22.01659966 -22.31159973 -22.70299911 -23.09160042 -23.48069954
#  -23.77440071 -24.07229996 -24.35829926 -24.65699959 -24.95089912
#  -25.23590088 -25.72710037 -26.12269974 -26.55929947 -26.99850082
#  -27.29240036 -27.57929993 -27.87879944 -28.17250061 -28.73080063
#  -29.27949905 -29.72570038 -30.10289955 -30.36240005 -30.69779968
#  -31.26549911 -31.90780067 -32.55550003 -33.19630051 -33.82619858
# ...

# %%
fig = plt.figure(figsize=(15,10))  # (w,h)
latmin=latOV.min()-10
latmax=latOV.max()+10
lonmin=lonOV.min()-10
lonmax=lonOV.max()+10

my_map0 = Basemap(projection='merc', lat_0=(latmin+latmax)/2, lon_0=(lonmin+lonmax)/2, 
resolution = 'i', 
llcrnrlon = lonmin-1, llcrnrlat= latmin-1,
urcrnrlon = lonmax+1, urcrnrlat = latmax+1, area_thresh = 10)

my_map0.drawcoastlines() 
my_map0.drawmapboundary()
my_map0.drawmeridians(np.arange(-120, 60, 10), labels=[1,0,0,1], size=18);
my_map0.drawparallels(np.arange(0, 80, 5), labels=[1,0,0,1], size=18);
my_map0.scatter(lonOV,latOV,latlon=True, linewidth='0', s=25);

plt.title('OVIDE section',size=17,y=1.08)
# Out:
# /home/albert/anaconda2/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.py:1623: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   fill_color = ax.get_axis_bgcolor()
# /home/albert/anaconda2/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.py:3222: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/albert/anaconda2/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.py:3231: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %%
tempOV=np.zeros((103,24))
saltOV=np.zeros((103,24))
depthOV=np.zeros((103,24))
latOV=np.zeros(103)
lonOV=np.zeros(103)


list=!ls /mnt/albert/equipes/meom/DATA_SET/OVIDE/29AH20120623_00*_00001_hy1.nc
for t in np.arange(103):
    file_OVIDE=list[t]
    ds=xr.open_dataset(file_OVIDE)
    latOV[t]=ds.latitude.values
    lonOV[t]=ds.longitude.values
    if len(ds.pressure.values) < 24:
        l=len(ds.pressure.values)
        tempOV[t,0:l]=ds.temperature.values
        saltOV[t,0:l]=ds.salinity.values
        depthOV[t,0:l]=gsw.conversions.z_from_p(ds.pressure.values, ds.latitude.values)
    else:
        tempOV[t,:]=ds.temperature.values
        saltOV[t,:]=ds.salinity.values
        depthOV[t,:]=gsw.conversions.z_from_p(ds.pressure.values, ds.latitude.values)

# %%
tempOV_mask=ma.masked_where(tempOV==0.,tempOV)
saltOV_mask=ma.masked_where(saltOV==0.,saltOV)

# %%
latOV
# Out:
# array([ 40.33259964,  40.33319855,  40.33440018,  40.33359909,
#         40.33069992,  40.33390045,  40.33430099,  40.33499908,
#         40.33679962,  40.33140182,  40.33240128,  40.33340073,
#         40.3321991 ,  40.55149841,  40.78730011,  41.08459854,
#         41.38359833,  41.68190002,  41.98329926,  42.28170013,
#         42.58169937,  42.87969971,  43.18080139,  43.47829819,
#         43.77920151,  44.07709885,  44.37760162,  44.67369843,
#         45.05130005,  45.42050171,  45.79349899,  46.17029953,
#         46.5447998 ,  46.917099  ,  47.28990173,  47.66529846,
#         48.03829956,  48.4131012 ,  48.7867012 ,  49.15879822,
#         49.5306015 ,  49.90430069,  50.40380096,  50.90200043,
#         51.40119934,  51.76929855,  52.14749908,  52.52000046,
#         52.89080048,  53.26539993,  53.6393013 ,  54.26670074,
#         54.76110077,  55.32860184,  55.88259888,  56.2519989 ,
#         56.62779999,  57.00400162,  57.37779999,  57.67490005,
# ...

# %%
latOV[14:90]
# Out:
# array([ 40.78730011,  41.08459854,  41.38359833,  41.68190002,
#         41.98329926,  42.28170013,  42.58169937,  42.87969971,
#         43.18080139,  43.47829819,  43.77920151,  44.07709885,
#         44.37760162,  44.67369843,  45.05130005,  45.42050171,
#         45.79349899,  46.17029953,  46.5447998 ,  46.917099  ,
#         47.28990173,  47.66529846,  48.03829956,  48.4131012 ,
#         48.7867012 ,  49.15879822,  49.5306015 ,  49.90430069,
#         50.40380096,  50.90200043,  51.40119934,  51.76929855,
#         52.14749908,  52.52000046,  52.89080048,  53.26539993,
#         53.6393013 ,  54.26670074,  54.76110077,  55.32860184,
#         55.88259888,  56.2519989 ,  56.62779999,  57.00400162,
#         57.37779999,  57.67490005,  57.97200012,  58.20800018,
#         58.40800095,  58.54990005,  58.72430038,  58.84270096,
#         58.91070175,  58.97359848,  59.04050064,  59.10250092,
#         59.16429901,  59.22859955,  59.29980087,  59.36270142,
# ...

# %%
yy=np.matlib.repmat(latOV,24,1)

# %%
depthOV.shape
# Out:
# (103, 24)

# %%
fig = plt.figure(figsize=(15,10))
ax = plt.subplot(111)
cmap=plt.get_cmap('rainbow')
pcolor=plt.contourf(yy[:,14:90].T,depthOV[14:90,:],tempOV_mask[14:90,:],np.arange(0,20,0.5),cmap=cmap)
#contour=ax.contour(np.squeeze(nlat),dep,1e4*ma.masked_invalid(np.squeeze(EKE)),[20,50,100,200,500,1000,2000],colors='k',alpha=0.5,linewidth=0.0001,antialiased=True)
#plt.clabel(contour, fmt='%i', colors='k', fontsize=14)
#plt.gca().invert_yaxis()
plt.gca().invert_xaxis()
ax.set_ylabel('Depth (m)',fontsize=20)
ax.set_xlabel('Latitude ($^\circ$N)',fontsize=20)
ax.tick_params(labelsize=20)
cbar=plt.colorbar()
cbar.ax.tick_params(labelsize=20)
plt.title('Temperature OVIDE',fontsize=20)
